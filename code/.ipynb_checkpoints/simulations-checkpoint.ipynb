# %% [markdown]
# # Iceberg simulations

# %%
# Import of packages (utils.py) and additional functions (utils.py, simu_late.py)
from src.utils import *
from src.simu_late import *
#import importlib
#import my_package

# %%
# Model configurations:
dict_in = {'config':{'seed:wind_form_drag_coef':1.5, 'seed:wind_form_drag_coef':1.5}}

# Input data
dict_in['input']=['cmems_mod_arc_phy_anfc_6km_detided_PT1H-i']#,'era5_2023_09_10-18.nc']#,'cmems_mod_arc_phy_my_topaz4_P1D-m','cmems_mod_glo_phy_anfc_0.083deg_PT1H-m','cmems_mod_glo_phy_my_0.083deg_P1D-m']

# Initial information
n=1
randspace=np.random.rand(n)
lengths, widths, sails, drafts = 81, 72, 2.9914802407484546, 21.199466273020537 #lengths, widths = randspace*(87-75)+75, randspace**(80-65)+65
lat, lon = 80.5794, 37.81915 
dict_in['seed']= {'lon': lon, 'lat': lat,
            'length': lengths, 'width': widths, 
            'sail': sails, 'draft': drafts, 
            'number': n, 
           'time': datetime(2023,9,10,12,36)}
dict_in['more']={'duration':0.5}

o1,o1_dataset = simu_late(dict_in) #o1 can be used to create plots. o1_dataset gives back an xr.dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 19
#      12 dict_in['seed']= {'lon': lon, 'lat': lat,
#      13             'length': lengths, 'width': widths,
#      14             'sail': sails, 'draft': drafts,
#      15             'number': n,
#      16            'time': datetime(2023,9,10,12,36)}
#      17 dict_in['more']={'duration':2}
# ---> 19 o1,o1_dataset = simu_late(dict_in) #o1 can be used to create plots. o1_dataset gives back an xr.dataset
#
# File ~/work/tutorials/sources/OpenDrift/src/simu_late.py:66, in simu_late(dict_in)
#      64     r = Reader(ds_corr,standard_name_mapping=inp['standard_name_mapping'],name=inp['name'])
#      65 else:
# ---> 66     r = Reader(inp['ref'],standard_name_mapping=inp['standard_name_mapping'],name=inp['name'])
#      67 #print(inp['ref'],inp['standard_name_mapping'],inp['name'])
#      68 reader_files = reader_files+[r]
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/readers/reader_netCDF_CF_generic.py:117, in Reader.__init__(self, filename, zarr_storage_options, name, proj4, standard_name_mapping, ensemble_member)
#      75 def __init__(self, filename=None, zarr_storage_options=None, name=None, proj4=None,
#      76              standard_name_mapping={}, ensemble_member=None):
#      77
#    (...)    114     #        except Exception as e:
#     115     #            raise ValueError(e)
# --> 117     self.Dataset = open_dataset_opendrift(source=filename, zarr_storage_options=zarr_storage_options)
#     119     self.Dataset = add_standard_name_for_surface_grib_variables(self.Dataset)
#     121     if name is None:
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/readers/__init__.py:65, in open_dataset_opendrift(source, zarr_storage_options, open_mfdataset_options, chunks)
#      63 else:
#      64     logger.info('Opening file with xr.open_dataset')
# ---> 65     ds = xr.open_dataset(source, decode_times=False)
#      67 # Decode CF times
#      68 offending = ds.filter_by_attrs(units='hours since analysis')  # Found e.g. in HYCOM datasets
#
# File /opt/conda/lib/python3.12/site-packages/xarray/backends/api.py:588, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     585     kwargs.update(backend_kwargs)
#     587 if engine is None:
# --> 588     engine = plugins.guess_engine(filename_or_obj)
#     590 if from_array_kwargs is None:
#     591     from_array_kwargs = {}
#
# File /opt/conda/lib/python3.12/site-packages/xarray/backends/plugins.py:217, in guess_engine(store_spec, must_support_groups)
#     214     if not is_remote_uri(store_spec_str) and not os.path.exists(store_spec_str):
#     215         raise FileNotFoundError(f"No such file: '{store_spec_str}'")
# --> 217 raise ValueError(error_msg)
#
# ValueError: did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'h5netcdf', 'scipy', 'zarr']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html

# %%
# ANALYSIS
o1.plot(fast=True)

# %%
#o1.plot_property('x_sea_water_velocity')

# %%
#o.animation(fast=True,filename='./simulation.gif',background=['sea_water_temperature','sea_water_temperature'],show_trajectories=True)#,color='z', buffer=.1
#Image(url='./simulation.gif')

# %%
#o1_dataset

# %% [markdown]
# REMAINING PROBLEMS:
# - does not save netcdf -> sttrb dtype error (but bin works)

# %%
#SAVE TO NETCDF -> still has sttr dtype error
#ds=o1
#for k, v in ds.attrs.items():
#    if isinstance(v, np.generic):  # catches numpy scalars like np.int32, np.float64
#        ds.attrs[k] = v.item()     # convert to native Python type
#    elif isinstance(v, type) and issubclass(v, np.generic):
#        # handles cases like: np.int32 (the type itself)
#        ds.attrs[k] = v.__name__   # convert to string like "int32"
#    print(k, type(ds.attrs[k]))
#ds.to_netcdf("./results.nc") #not sure why not work no dri or file

#SAVE TO BINARY, #WORKS!
#import pickle 
#pickle.dump(o1,open("../results/results.bin",'wb'))
