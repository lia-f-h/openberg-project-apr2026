# %% [markdown]
# # Iceberg simulations

# %%
# Import of packages (utils.py) and additional functions (utils.py, simu_late.py)
from src.utils import *
from src.simu_late import *

import importlib
from src.simu_late import *

# %%
# Model configurations:
dict_in = {'config':{'seed:wind_form_drag_coef':1.5, 'seed:wind_form_drag_coef':1.5}}

# Input data
dict_in['input']=['cmems_mod_arc_phy_anfc_6km_detided_PT1H-i',{'era5':{'ref':'../input/era5_2023_09_10-18.nc'}}]#,'cmems_mod_arc_phy_my_topaz4_P1D-m','cmems_mod_glo_phy_anfc_0.083deg_PT1H-m','cmems_mod_glo_phy_my_0.083deg_P1D-m']

# Initial information
n=1
randspace=np.random.rand(n)
lengths, widths, sails, drafts = 81, 72, 2.9914802407484546, 21.199466273020537 #lengths, widths = randspace*(87-75)+75, randspace**(80-65)+65
lat, lon = 80.5794, 37.81915 
dict_in['seed']= {'lon': lon, 'lat': lat,
            'length': lengths, 'width': widths, 
            'sail': sails, 'draft': drafts, 
            'number': n, 
           'time': datetime(2023,9,10,12,36)}
dict_in['more']={'duration':8}

o1,o1_ds = simu_late(dict_in) #o1 can be used to create plots. o1_dataset gives back an xr.dataset
# Out:
# Input used:  ['cmems_mod_arc_phy_anfc_6km_detided_PT1H-i', 'era5']
# Fetching catalogue 1:   0%|          | 0/2 [00:00<?, ?it/s]
# Fetching products:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching catalogue 1: 100%|██████████| 2/2 [00:00<00:00, 31.81it/s]
# INFO - 2026-04-22T14:48:55Z - Selected dataset version: "202311"
# INFO - 2026-04-22T14:48:55Z - Selected dataset part: "default"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 19
#      12 dict_in['seed']= {'lon': lon, 'lat': lat,
#      13             'length': lengths, 'width': widths,
#      14             'sail': sails, 'draft': drafts,
#      15             'number': n,
#      16            'time': datetime(2023,9,10,12,36)}
#      17 dict_in['more']={'duration':8}
# ---> 19 o1,o1_ds = simu_late(dict_in) #o1 can be used to create plots. o1_dataset gives back an xr.dataset
#
# File ~/work/tutorials/sources/OpenDrift/src/simu_late.py:129, in simu_late(dict_in)
#     125 #correct iceberg size
#     126
#     127 #RUN SIMULATIONS
#     128 if 'duration' in dict_in['more']: simulation_days = dict_in['more']['duration'] # Simulation time in days. Negative sign causes backwards simulation.
# --> 129 oi = o.run(duration=timedelta(days=simulation_days))
#     131 print('\a')
#     132 return o,oi
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/models/basemodel/__init__.py:180, in require_mode.<locals>._decorator.<locals>.inner(self, *args, **kwargs)
#     177     else:
#     178         raise WrongMode(mode, self.mode, error)
# --> 180 r = func(self, *args, **kwargs)
#     182 if post_next_mode:
#     183     next_mode()
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/models/basemodel/__init__.py:2162, in OpenDriftSimulation.run(self, time_step, steps, time_step_output, duration, end_time, outfile, export_variables, export_buffer_length, stop_on_error)
#    2156 logger.debug('---------------------------------')
#    2158 ###############################################
#    2159 # Get environment data for all active elements
#    2160 ###############################################
#    2161 self.environment, self.environment_profiles, missing = \
# -> 2162     self.env.get_environment(list(self.required_variables),
#    2163                          self.time,
#    2164                          self.elements.lon,
#    2165                          self.elements.lat,
#    2166                          self.elements.z,
#    2167                          self.required_profiles,
#    2168                          self.profiles_depth,
#    2169                          element_ID = self.elements.ID)
#    2171 self.calculate_missing_environment_variables()
#    2173 self.report_missing_variables(missing)
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/models/basemodel/environment.py:637, in Environment.get_environment(self, variables, time, lon, lat, z, profiles, profiles_depth, element_ID)
#     634     else:
#     635         profiles_from_reader = None
#     636     env_tmp, env_profiles_tmp = \
# --> 637         reader.get_variables_interpolated(
#     638             variable_group, profiles = profiles_from_reader,
#     639             profiles_depth = profiles_depth, time = time,
#     640             lon=lon[missing_indices], lat=lat[missing_indices],
#     641             z=z[missing_indices], rotate_to_proj=self.proj_latlon)
#     643 except NotCoveredError as e:
#     644     logger.info(e)
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/readers/basereader/variables.py:913, in Variables.get_variables_interpolated(self, variables, profiles, profiles_depth, time, lon, lat, z, rotate_to_proj)
#     910 lon = self.modulate_longitude(lon)
#     911 x, y = self.lonlat2xy(lon, lat)
# --> 913 env, env_profiles = self.get_variables_interpolated_xy(
#     914     variables, profiles, profiles_depth, time, x, y, z, rotate_to_proj)
#     916 return env, env_profiles
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/readers/basereader/variables.py:779, in Variables.get_variables_interpolated_xy(self, variables, profiles, profiles_depth, time, x, y, z, rotate_to_proj)
#     776     variables.remove(v)
#     777 variables.extend(list(set(derived_input)))
# --> 779 env, env_profiles = self._get_variables_interpolated_(
#     780     variables, profiles, profiles_depth, time, x, y, z)
#     782 # Calculate derived variables
#     783 if len(derived) > 0:
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/readers/basereader/structured.py:301, in StructuredReader._get_variables_interpolated_(self, variables, profiles, profiles_depth, time, reader_x, reader_y, z)
#     298     self.var_block_after[blockvars_after] = block_before
#     299 else:
#     300     reader_data_dict = self.__convolve_block__(
# --> 301         self.get_variables(blockvariables_after, time_after, mx,
#     302                            my, mz))
#     303     self.var_block_after[blockvars_after] = \
#     304         ReaderBlock(
#     305             reader_data_dict,
#     306             interpolation_horizontal=self.interpolation,
#     307             wrap_x=self.global_coverage())
#     308     try:
#
# File /opt/conda/lib/python3.12/site-packages/opendrift/readers/reader_netCDF_CF_generic.py:551, in Reader.get_variables(self, requested_variables, time, x, y, z, indrealization)
#     548     variables[par] = np.ma.masked_invalid(variables[par])
#     550 # Mask values outside domain
# --> 551 variables[par] = np.ma.array(variables[par],
#     552                              ndmin=2, mask=False)
#     553 # Mask extreme values which might have slipped through
#     554 with np.errstate(invalid='ignore'):
#
# File /opt/conda/lib/python3.12/site-packages/numpy/ma/core.py:6853, in array(data, dtype, copy, order, mask, fill_value, keep_mask, hard_mask, shrink, subok, ndmin)
#    6843 def array(data, dtype=None, copy=False, order=None,
#    6844           mask=nomask, fill_value=None, keep_mask=True,
#    6845           hard_mask=False, shrink=True, subok=True, ndmin=0):
#    6846     """
#    6847     Shortcut to MaskedArray.
#    6848
#    (...)   6851
#    6852     """
# -> 6853     return MaskedArray(data, mask=mask, dtype=dtype, copy=copy,
#    6854                        subok=subok, keep_mask=keep_mask,
#    6855                        hard_mask=hard_mask, fill_value=fill_value,
#    6856                        ndmin=ndmin, shrink=shrink, order=order)
#
# File /opt/conda/lib/python3.12/site-packages/numpy/ma/core.py:2885, in MaskedArray.__new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order)
#    2883 # Process data.
#    2884 copy = None if not copy else True
# -> 2885 _data = np.array(data, dtype=dtype, copy=copy,
#    2886                  order=order, subok=True, ndmin=ndmin)
#    2887 _baseclass = getattr(data, '_baseclass', type(_data))
#    2888 # Check that we're not erasing the mask.
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/common.py:181, in AbstractArray.__array__(self, dtype, copy)
#     179         except TypeError:
#     180             copy = False
# --> 181 return np.array(self.values, dtype=dtype, copy=copy)
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/variable.py:555, in Variable.values(self)
#     552 @property
#     553 def values(self) -> np.ndarray:
#     554     """The variable's data as a numpy.ndarray"""
# --> 555     return _as_array_or_item(self._data)
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/variable.py:335, in _as_array_or_item(data)
#     321 def _as_array_or_item(data):
#     322     """Return the given values as a numpy array, or as an individual item if
#     323     it's a 0d datetime64 or timedelta64 array.
#     324
#    (...)    333     TODO: remove this (replace with np.asarray) once these issues are fixed
#     334     """
# --> 335     data = np.asarray(data)
#     336     if data.ndim == 0:
#     337         kind = data.dtype.kind
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/indexing.py:604, in ExplicitlyIndexed.__array__(self, dtype, copy)
#     599 def __array__(
#     600     self, dtype: DTypeLike | None = None, /, *, copy: bool | None = None
#     601 ) -> np.ndarray:
#     602     # Leave casting to an array up to the underlying array type.
#     603     if Version(np.__version__) >= Version("2.0.0"):
# --> 604         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     605     else:
#     606         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/indexing.py:970, in MemoryCachedArray.get_duck_array(self)
#     969 def get_duck_array(self):
# --> 970     duck_array = self.array.get_duck_array()
#     971     # ensure the array object is cached in-memory
#     972     self.array = as_indexable(duck_array)
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/indexing.py:924, in CopyOnWriteArray.get_duck_array(self)
#     923 def get_duck_array(self):
# --> 924     return self.array.get_duck_array()
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/indexing.py:764, in LazilyIndexedArray.get_duck_array(self)
#     761 from xarray.backends.common import BackendArray
#     763 if isinstance(self.array, BackendArray):
# --> 764     array = self.array[self.key]
#     765 else:
#     766     array = apply_indexer(self.array, self.key)
#
# File /opt/conda/lib/python3.12/site-packages/xarray/backends/zarr.py:316, in ZarrArrayWrapper.__getitem__(self, key)
#     314 elif isinstance(key, indexing.OuterIndexer):
#     315     method = self._oindex
# --> 316 return indexing.explicit_indexing_adapter(
#     317     key, array.shape, indexing.IndexingSupport.VECTORIZED, method
#     318 )
#
# File /opt/conda/lib/python3.12/site-packages/xarray/core/indexing.py:1156, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1134 """Support explicit indexing by delegating to a raw indexing method.
#    1135
#    1136 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)   1153 Indexing result, in the form of a duck numpy-array.
#    1154 """
#    1155 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1156 result = raw_indexing_method(raw_key.tuple)
#    1157 if numpy_indices.tuple:
#    1158     # index the loaded duck array
#    1159     indexable = as_indexable(result)
#
# File /opt/conda/lib/python3.12/site-packages/xarray/backends/zarr.py:273, in ZarrArrayWrapper._oindex(self, key)
#     272 def _oindex(self, key):
# --> 273     return self._array.oindex[key]
#
# File /opt/conda/lib/python3.12/site-packages/zarr/core/indexing.py:998, in OIndex.__getitem__(self, selection)
#     996 new_selection = ensure_tuple(new_selection)
#     997 new_selection = replace_lists(new_selection)
# --> 998 return self.array.get_orthogonal_selection(
#     999     cast("OrthogonalSelection", new_selection), fields=fields
#    1000 )
#
# File /opt/conda/lib/python3.12/site-packages/zarr/core/array.py:3303, in Array.get_orthogonal_selection(self, selection, out, fields, prototype)
#    3301     prototype = default_buffer_prototype()
#    3302 indexer = OrthogonalIndexer(selection, self.shape, self.metadata.chunk_grid)
# -> 3303 return sync(
#    3304     self.async_array._get_selection(
#    3305         indexer=indexer, out=out, fields=fields, prototype=prototype
#    3306     )
#    3307 )
#
# File /opt/conda/lib/python3.12/site-packages/zarr/core/sync.py:152, in sync(coro, loop, timeout)
#     148     pass
#     150 future = asyncio.run_coroutine_threadsafe(_runner(coro), loop)
# --> 152 finished, unfinished = wait([future], return_when=asyncio.ALL_COMPLETED, timeout=timeout)
#     153 if len(unfinished) > 0:
#     154     raise TimeoutError(f"Coroutine {coro} failed to finish within {timeout} s")
#
# File /opt/conda/lib/python3.12/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File /opt/conda/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/conda/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File /opt/conda/lib/python3.12/site-packages/stack_data/core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File /opt/conda/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File /opt/conda/lib/python3.12/site-packages/stack_data/core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File /opt/conda/lib/python3.12/site-packages/stack_data/utils.py:164, in _pygmented_with_ranges(formatter, code, ranges)
#     161             length += len(value)
#     162             yield ttype, value
# --> 164 lexer = MyLexer(stripnl=False)
#     165 try:
#     166     highlighted = pygments.highlight(code, lexer, formatter)
#
# File /opt/conda/lib/python3.12/site-packages/pygments/lexer.py:660, in RegexLexerMeta.__call__(cls, *args, **kwds)
#     658         pass
#     659     else:
# --> 660         cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#     662 return type.__call__(cls, *args, **kwds)
#
# File /opt/conda/lib/python3.12/site-packages/pygments/lexer.py:599, in RegexLexerMeta.process_tokendef(cls, name, tokendefs)
#     597 tokendefs = tokendefs or cls.tokens[name]
#     598 for state in list(tokendefs):
# --> 599     cls._process_state(tokendefs, processed, state)
#     600 return processed
#
# File /opt/conda/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File /opt/conda/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File /opt/conda/lib/python3.12/site-packages/pygments/lexer.py:579, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     576 assert type(tdef) is tuple, f"wrong rule def {tdef!r}"
#     578 try:
# --> 579     rex = cls._process_regex(tdef[0], rflags, state)
#     580 except Exception as err:
#     581     raise ValueError(f"uncompilable regex {tdef[0]!r} in state {state!r} of {cls!r}: {err}") from err
#
# File /opt/conda/lib/python3.12/site-packages/pygments/lexer.py:507, in RegexLexerMeta._process_regex(cls, regex, rflags, state)
#     505 """Preprocess the regular expression component of a token definition."""
#     506 if isinstance(regex, Future):
# --> 507     regex = regex.get()
#     508 return re.compile(regex, rflags).match
#
# File /opt/conda/lib/python3.12/site-packages/pygments/lexer.py:495, in words.get(self)
#     494 def get(self):
# --> 495     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:91, in regex_opt(strings, prefix, suffix)
#      83 """Return a compiled regex that matches any string in the given list.
#      84
#      85 The strings to match must be literal strings, not regexes.  They will be
#    (...)     88 *prefix* and *suffix* are pre- and appended to the final regex.
#      89 """
#      90 strings = sorted(strings)
# ---> 91 return prefix + regex_opt_inner(strings, '(') + suffix
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
#     [... skipping similar frames: <genexpr> at line 77 (5 times), regex_opt_inner at line 77 (5 times)]
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/conda/lib/python3.12/site-packages/pygments/regexopt.py:62, in regex_opt_inner(strings, open_paren)
#      59     plen = len(prefix)
#      60     # we have a prefix for all strings
#      61     # print '-> prefix:', prefix
# ---> 62     return open_paren + escape(prefix) \
#      63         + regex_opt_inner([s[plen:] for s in strings], '(?:') \
#      64         + close_paren
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
#
# File /opt/conda/lib/python3.12/re/__init__.py:260, in escape(pattern)
#     256 """
#     257 Escape special characters in a string.
#     258 """
#     259 if isinstance(pattern, str):
# --> 260     return pattern.translate(_special_chars_map)
#     261 else:
#     262     pattern = str(pattern, 'latin1')
#
# KeyboardInterrupt:

# %%
# ANALYSIS
o1.plot(fast=True)

# %%
#More simulations for comparison
dict_in['input']=['topaz4',{'era5':{'ref':'../input/era5_2023_09_10-18.nc'}}]
o2,o2_ds = simu_late(dict_in) 

dict_in['input']=['glorys',{'era5':{'ref':'../input/era5_2023_09_10-18.nc'}}]
o3,o3_ds = simu_late(dict_in)

# %%
o1.plot(compare=[o2,o3], legend=['Topaz5', 'Topaz4', 'Glorys'], background=['x_sea_water_velocity', 'y_sea_water_velocity'], fast=False,filename='../results/opendrift_demo.png')

# %%
o1.plot_property('x_wind')#'x_sea_water_velocity')

# %%
#o.animation(fast=True,filename='./simulation.gif',background=['sea_water_temperature','sea_water_temperature'],show_trajectories=True)#,color='z', buffer=.1
#Image(url='./simulation.gif')

# %%
#o1_dataset

# %% [markdown]
# REMAINING PROBLEMS:
# - does not save netcdf -> sttrb dtype error (but bin works)

# %%
#SAVE TO NETCDF -> still has sttr dtype error
#ds=o1
#for k, v in ds.attrs.items():
#    if isinstance(v, np.generic):  # catches numpy scalars like np.int32, np.float64
#        ds.attrs[k] = v.item()     # convert to native Python type
#    elif isinstance(v, type) and issubclass(v, np.generic):
#        # handles cases like: np.int32 (the type itself)
#        ds.attrs[k] = v.__name__   # convert to string like "int32"
#    print(k, type(ds.attrs[k]))
#ds.to_netcdf("./results.nc") #not sure why not work no dri or file

#SAVE TO BINARY, #WORKS!
#import pickle 
#pickle.dump(o1,open("../results/results.bin",'wb'))

# %%
o1.get_property('sail')
